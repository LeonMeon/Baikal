# %%
import fits

# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader
#np.random.seed(1)
plt.style.use("seaborn-talk") #"classic" "seaborn-talk" "seaborn"
path_to_h5 =  "/home/leonov/Baikal/Gr_big_data/mc_baikal_norm_cut-8_ordered_with_MCarlo.h5"

# %%
with h5py.File(path_to_h5, 'r') as hf:
    print(hf["train"].keys())
# Out:
# <KeysViewHDF5 ['data', 'ev_chars', 'ev_ids', 'labels_full', 'labels_num_mu', 'labels_one_mu', 'labels_particle', 'labels_signal_noise', 'labels_track_type', 'mask']>

# %%
import matplotlib.pyplot as plt
with h5py.File(path_to_h5, 'r') as hf:
    plt.figure( figsize = (12,10))
    plt.hist(np.log(hf["train/ev_chars"][:,2] + 1 ),bins = 100)

# %%
with h5py.File(path_to_h5, 'r') as hf:
    print( np.min(hf["train/ev_chars"][:,2]))
# Out:
# 20.40341

# %%
with h5py.File(path_to_h5, 'r') as hf:
    print(hf["train/ev_chars"].shape)
# Out:
# (1365465, 6)

# %%
with h5py.File(path_to_h5, 'r') as hf:
    plt.hist(hf["train/ev_chars"][:,0])

# %%
with h5py.File(path_to_h5, 'r') as hf:
    plt.hist(hf["train/ev_chars"][:,1])

# %%
with h5py.File(path_to_h5, 'r') as hf:
    plt.hist(np.log(hf["train/ev_chars"][:,2]) )

# %%
with h5py.File(path_to_h5, 'r') as hf:
    plt.hist(hf["train/ev_chars"][:,3], bins =100)

# %%
with h5py.File(path_to_h5, 'r') as hf:
    plt.hist(hf["train/ev_chars"][:,4])

# %%
with h5py.File(path_to_h5, 'r') as hf:
    plt.hist(hf["train/ev_chars"][:,5])

# %%
with h5py.File(path_to_h5, 'r') as hf:
    plt.hist(hf["train"].keys())
